# %%
import numpy as np
from pandas import to_datetime as dt
import matplotlib.pyplot as plt

# %%
data={"Date": dt(["2004-01-08", "2004-02-06", "2004-03-4", "2004-04-30", "2004-05-5", "2004-06-17","2004-07-01", "2004-08-21", "2004-09-05", "2004-10-26", "2004-11-30", "2004-12-21", "2004-12-16"]),
      "Value": [10,1,9,2,62,45,87,36,60,25,75,17,90,]}

# %%
df = pd.DataFrame(data)
df.set_index("Date", inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, df["Value"], marker='o')
plt.xlabel("Data")
plt.ylabel("Value")
plt.title("Time Series with seasonality")
plt.grid(True)
plt.show()
