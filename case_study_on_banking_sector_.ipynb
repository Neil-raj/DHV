# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
age_groups = ['18-25', '26-30', '31-35', '36-40', '41-45', '46-50', '51-55', '56-60', '61-65', '66-70', '71-75', '76-80']


num_age_groups = len(age_groups)

total_loans = np.random.randint(100, 1000, size=num_age_groups)
bad_loans = np.random.randint(10, total_loans.max() // 4, size=num_age_groups)
good_loans = total_loans - bad_loans


percentage_bad_loans = (bad_loans / total_loans) * 100
percentage_good_loans = (good_loans / total_loans) * 100


data = {
    'Age Group': age_groups,
    'Total Number of Loans': total_loans,
    'Number of Bad Loans': bad_loans,
    'Number of Good Loans': good_loans,
    'Percentage of Bad Loans': percentage_bad_loans,
    'Percentage of Good Loans': percentage_good_loans
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Age Group  Total Number of Loans  Number of Bad Loans  \
# 0      18-25                    685                  112
# 1      26-30                    749                   16
# 2      31-35                    710                   44
# 3      36-40                    683                   45
# 4      41-45                    686                   18
# 5      46-50                    291                  113
# 6      51-55                    496                   49
# 7      56-60                    518                   76
# 8      61-65                    453                  142
# 9      66-70                    332                  135
# 10     71-75                    579                   59
# 11     76-80                    862                   14
#
#     Number of Good Loans  Percentage of Bad Loans  Percentage of Good Loans
# 0                    573                16.350365                 83.649635
# 1                    733                 2.136182                 97.863818
# 2                    666                 6.197183                 93.802817
# 3                    638                 6.588580                 93.411420
# 4                    668                 2.623907                 97.376093
# 5                    178                38.831615                 61.168385
# 6                    447                 9.879032                 90.120968
# 7                    442                14.671815                 85.328185
# 8                    311                31.346578                 68.653422
# 9                    197                40.662651                 59.337349
# 10                   520                10.189983                 89.810017
# 11                   848                 1.624130                 98.375870

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Age Group'], df['Number of Bad Loans'], color='red', label='Bad Loans')
plt.bar(df['Age Group'], df['Number of Good Loans'], color='green', label='Good Loans', bottom=df['Number of Bad Loans'])
plt.title('Distribution of Good and Bad Loans Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Loans')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
